# %%
#import data manipulation library
import pandas as pd
import numpy as np
#import data library
import seaborn as sns
import matplotlib.pyplot as plt
# import data filter warning
import warnings
warnings.filterwarnings('ignore')

# %%
#import data
url='https://raw.githubusercontent.com/rajpande2151/SUPPLYCHAIN/refs/heads/main/SCM.csv'
df=pd.read_csv(url)

df.sample(frac=1)
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 10811     WH_110811     EID_60811         Rural            Large  North
# 5361      WH_105361     EID_55361         Rural            Large   West
# 18234     WH_118234     EID_68234         Rural            Small  North
# 3341      WH_103341     EID_53341         Rural              Mid   West
# 18468     WH_118468     EID_68468         Rural              Mid   West
# ...             ...           ...           ...              ...    ...
# 2854      WH_102854     EID_52854         Rural              Mid  North
# 16000     WH_116000     EID_66000         Rural            Large  North
# 18911     WH_118911     EID_68911         Rural            Small  North
# 13258     WH_113258     EID_63258         Rural            Large  North
# 11793     WH_111793     EID_61793         Rural              Mid  North
#
#       WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22150 entries, 0 to 22149
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ware_house_ID                 22150 non-null  object
#  1   WH_Manager_ID                 22150 non-null  object
#  2   Location_type                 22150 non-null  object
#  3   WH_capacity_size              22150 non-null  object
#  4   zone                          22150 non-null  object
#  5   WH_regional_zone              22150 non-null  object
#  6   num_refill_req_l3m            22150 non-null  int64
#  7   transport_issue_l1y           22150 non-null  int64
#  8   Competitor_in_mkt             22150 non-null  int64
#  9   retail_shop_num               22150 non-null  int64
#  10  wh_owner_type                 22150 non-null  object
#  11  distributor_num               22150 non-null  int64
# ...

# %%
#Checking data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22150 entries, 0 to 22149
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ware_house_ID                 22150 non-null  object
#  1   WH_Manager_ID                 22150 non-null  object
#  2   Location_type                 22150 non-null  object
#  3   WH_capacity_size              22150 non-null  object
#  4   zone                          22150 non-null  object
#  5   WH_regional_zone              22150 non-null  object
#  6   num_refill_req_l3m            22150 non-null  int64
#  7   transport_issue_l1y           22150 non-null  int64
#  8   Competitor_in_mkt             22150 non-null  int64
#  9   retail_shop_num               22150 non-null  int64
#  10  wh_owner_type                 22150 non-null  object
#  11  distributor_num               22150 non-null  int64
# ...

# %%
#Checking Data Description : Univariate Analysis
'''
The following data is found to be Non-Normal Distributed, Since Mean ! =Median
'''
df.describe()
# Out:
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# count        22150.000000         22150.000000       22150.000000
# mean             4.097020             0.777201           3.103928
# std              2.606289             1.201747           1.142886
# min              0.000000             0.000000           0.000000
# 25%              2.000000             0.000000           2.000000
# 50%              4.000000             0.000000           3.000000
# 75%              6.000000             1.000000           4.000000
# max              8.000000             5.000000          12.000000
#
#        retail_shop_num  distributor_num  flood_impacted   flood_proof  \
# count     22150.000000     22150.000000    22150.000000  22150.000000
# mean       4983.115711        42.386998        0.098691      0.054492
# std        1050.634225        16.057730        0.298253      0.226991
# min        1821.000000        15.000000        0.000000      0.000000
# ...

# %%
# Checking Null Values in Dataset
df.isnull().sum().plot(kind = 'barh',cmap ='viridis')
plt.title('Bar Plot Showing Null Values in Dataset')
plt.axvline(805)
plt.show()

# %%
#Calculate Missing value percentage :
(df['approved_wh_govt_certificate'].isnull().sum() / len(df['approved_wh_govt_certificate']))*100
# Out:
# 3.6343115124153504

# %%
#Calculate Missing value percentage :
(df['wh_est_year'].isnull().sum() / len(df['wh_est_year']))*100
# Out:
# 47.60722347629797

# %%
df['wh_est_year'].value_counts().head(10)
# Out:
# wh_est_year
# 2000.0    495
# 2002.0    479
# 2006.0    475
# 2014.0    474
# 2007.0    465
# 2004.0    458
# 2016.0    454
# 2001.0    450
# 1998.0    449
# 2018.0    448
# Name: count, dtype: int64

# %%
df['wh_est_year'].median()
# Out:
# 2009.0

# %%
df['wh_est_year'].mean()
# Out:
# 2009.4012063765617

# %%
df['wh_est_year'].plot (kind =('hist'))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Imputing the missing value column
df['wh_est_year'].fillna(2009,inplace=True)

# %%
df['approved_wh_govt_certificate'].fillna(df['approved_wh_govt_certificate'].mode(),inplace = True)

# %%
# import data manipulation libraries 
import pandas as pd 
import numpy as np

# import data visualization  library
import seaborn as sns
import matplotlib.pyplot as plt

#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#import data using url from github
url = 'https://raw.githubusercontent.com/preet-pandey/SUPPLYCHAIN/refs/heads/main/SCM.csv'
df = pd.read_csv(url)
df.sample(frac = 1)
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 4568      WH_104568     EID_54568         Rural              Mid  South
# 12798     WH_112798     EID_62798         Rural              Mid  North
# 3904      WH_103904     EID_53904         Rural            Small  North
# 15983     WH_115983     EID_65983         Rural            Small  South
# 21662     WH_121662     EID_71662         Rural            Large   West
# ...             ...           ...           ...              ...    ...
# 10476     WH_110476     EID_60476         Rural              Mid  South
# 1319      WH_101319     EID_51319         Urban            Large  North
# 17331     WH_117331     EID_67331         Urban            Large  North
# 11382     WH_111382     EID_61382         Rural              Mid   West
# 12819     WH_112819     EID_62819         Rural            Large  South
#
#       WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# ...

# %%
# checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22150 entries, 0 to 22149
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ware_house_ID                 22150 non-null  object
#  1   WH_Manager_ID                 22150 non-null  object
#  2   Location_type                 22150 non-null  object
#  3   WH_capacity_size              22150 non-null  object
#  4   zone                          22150 non-null  object
#  5   WH_regional_zone              22150 non-null  object
#  6   num_refill_req_l3m            22150 non-null  int64
#  7   transport_issue_l1y           22150 non-null  int64
#  8   Competitor_in_mkt             22150 non-null  int64
#  9   retail_shop_num               22150 non-null  int64
#  10  wh_owner_type                 22150 non-null  object
#  11  distributor_num               22150 non-null  int64
# ...

# %%
df["workers_num"].isnull().sum() / len(df['workers_num'])*100
# Out:
# 3.959367945823928

# %%
df['workers_num'].median()
# Out:
# 28.0

# %%
df['workers_num'].mean()
# Out:
# 28.93639825130447

# %%
df['workers_num'].quantile(0.75),df['workers_num'].quantile(0.25)
#whenever we imputing mean or median or by any constant value then please ensure imputation must be integer value not a decimal
# Out:
# (33.0, 24.0)

# %%
df['workers_num'].fillna(28,inplace = True)

# %%
#how to check if any null values 
df.isnull().sum()
# Out:
# Ware_house_ID                       0
# WH_Manager_ID                       0
# Location_type                       0
# WH_capacity_size                    0
# zone                                0
# WH_regional_zone                    0
# num_refill_req_l3m                  0
# transport_issue_l1y                 0
# Competitor_in_mkt                   0
# retail_shop_num                     0
# wh_owner_type                       0
# distributor_num                     0
# flood_impacted                      0
# flood_proof                         0
# electric_supply                     0
# dist_from_hub                       0
# workers_num                         0
# wh_est_year                     10545
# storage_issue_reported_l3m          0
# temp_reg_mach                       0
# approved_wh_govt_certificate      805
# wh_breakdown_l3m                    0
# govt_check_l3m                      0
# product_wg_ton                      0
# dtype: int64

# %%
#separate categorical and numerical columns 
categorical_columns = df.select_dtypes(include = 'object')

# %%
numerical_columns = df.select_dtypes(exclude = 'object')

# %%
categorical_columns
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 0         WH_100000     EID_50000         Urban            Small   West
# 1         WH_100001     EID_50001         Rural            Large  North
# 2         WH_100002     EID_50002         Rural              Mid  South
# 3         WH_100003     EID_50003         Rural              Mid  North
# 4         WH_100004     EID_50004         Rural            Large  North
# ...             ...           ...           ...              ...    ...
# 22145     WH_122145     EID_72145         Rural            Large  North
# 22146     WH_122146     EID_72146         Rural            Small  South
# 22147     WH_122147     EID_72147         Rural            Large  North
# 22148     WH_122148     EID_72148         Rural            Large  North
# 22149     WH_122149     EID_72149         Rural              Mid   East
#
#       WH_regional_zone  wh_owner_type approved_wh_govt_certificate
# ...

# %%
numerical_columns
# Out:
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                       3                    1                  2
# 1                       0                    0                  4
# 2                       1                    0                  4
# 3                       7                    4                  2
# 4                       3                    1                  2
# ...                   ...                  ...                ...
# 22145                   8                    1                  3
# 22146                   3                    1                  3
# 22147                   7                    2                  2
# 22148                   6                    2                  4
# 22149                   7                    2                  9
#
#        retail_shop_num  distributor_num  flood_impacted  flood_proof  \
# 0                 4651               24               0            1
# ...

# %%
df.drop(columns = ['Ware_house_ID','WH_Manager_ID'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#   Location_type WH_capacity_size   zone WH_regional_zone  num_refill_req_l3m  \
# 0         Urban            Small   West           Zone 6                   3
# 1         Rural            Large  North           Zone 5                   0
# 2         Rural              Mid  South           Zone 2                   1
# 3         Rural              Mid  North           Zone 3                   7
# 4         Rural            Large  North           Zone 5                   3
#
#    transport_issue_l1y  Competitor_in_mkt  retail_shop_num  wh_owner_type  \
# 0                    1                  2             4651         Rented
# 1                    0                  4             6217  Company Owned
# 2                    0                  4             4306  Company Owned
# 3                    4                  2             6000         Rented
# 4                    1                  2             4740  Company Owned
#
# ...

# %%
westzone = df[df['zone']=='West'].value_counts()

# %%
df['zone'].value_counts().plot(kind = 'pie',autopct = '%1.2f',explode = [0.01,0.01,0.01,0.01])
# Out:
# <Axes: ylabel='count'>

# %%
# evaluate the data of west zone

southzone = df[df['zone'] == 'South']
southzone
# Out:
#       Location_type WH_capacity_size   zone WH_regional_zone  \
# 2             Rural              Mid  South           Zone 2
# 8             Rural            Small  South           Zone 6
# 9             Rural            Small  South           Zone 6
# 13            Rural              Mid  South           Zone 4
# 19            Rural            Small  South           Zone 1
# ...             ...              ...    ...              ...
# 22133         Rural            Large  South           Zone 5
# 22135         Urban            Large  South           Zone 5
# 22136         Urban            Small  South           Zone 1
# 22144         Rural            Small  South           Zone 6
# 22146         Rural            Small  South           Zone 6
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 2                       1                    0                  4
# 8                       8                    1                  4
# ...

# %%
# evaluate the data of east zone

eastzone = df[df['zone'] == 'East']
eastzone
# Out:
#       Location_type WH_capacity_size  zone WH_regional_zone  \
# 37            Rural              Mid  East           Zone 3
# 86            Rural            Small  East           Zone 1
# 127           Rural            Small  East           Zone 1
# 313           Rural              Mid  East           Zone 3
# 367           Rural              Mid  East           Zone 4
# ...             ...              ...   ...              ...
# 21981         Rural            Small  East           Zone 6
# 22017         Rural            Small  East           Zone 1
# 22058         Rural              Mid  East           Zone 3
# 22091         Rural              Mid  East           Zone 4
# 22149         Rural              Mid  East           Zone 4
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 37                      0                    1                  8
# 86                      4                    0                  4
# ...

# %%
categorical_columns
# Out:
#       Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 0         WH_100000     EID_50000         Urban            Small   West
# 1         WH_100001     EID_50001         Rural            Large  North
# 2         WH_100002     EID_50002         Rural              Mid  South
# 3         WH_100003     EID_50003         Rural              Mid  North
# 4         WH_100004     EID_50004         Rural            Large  North
# ...             ...           ...           ...              ...    ...
# 22145     WH_122145     EID_72145         Rural            Large  North
# 22146     WH_122146     EID_72146         Rural            Small  South
# 22147     WH_122147     EID_72147         Rural            Large  North
# 22148     WH_122148     EID_72148         Rural            Large  North
# 22149     WH_122149     EID_72149         Rural              Mid   East
#
#       WH_regional_zone  wh_owner_type approved_wh_govt_certificate
# ...

# %%
df
#whenever you are encoding from any column from dataset make sure we should not use the label encoder , one hot encoder ,ordinal encoder for target column
# Out:
#       Location_type WH_capacity_size   zone WH_regional_zone  \
# 0             Urban            Small   West           Zone 6
# 1             Rural            Large  North           Zone 5
# 2             Rural              Mid  South           Zone 2
# 3             Rural              Mid  North           Zone 3
# 4             Rural            Large  North           Zone 5
# ...             ...              ...    ...              ...
# 22145         Rural            Large  North           Zone 6
# 22146         Rural            Small  South           Zone 6
# 22147         Rural            Large  North           Zone 6
# 22148         Rural            Large  North           Zone 6
# 22149         Rural              Mid   East           Zone 4
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                       3                    1                  2
# 1                       0                    0                  4
# ...

# %%
df['Location_type'].value_counts()
# Out:
# Location_type
# Rural    20334
# Urban     1816
# Name: count, dtype: int64

# %%
from  sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Location_type'] = le.fit_transform(df['Location_type'])

# %%
df['Location_type'].value_counts()
# Out:
# Location_type
# 0    20334
# 1     1816
# Name: count, dtype: int64

# %%
df['WH_capacity_size'].value_counts()
# Out:
# WH_capacity_size
# Large    8968
# Mid      8902
# Small    4280
# Name: count, dtype: int64

# %%
df['WH_capacity_size'] = le.fit_transform(df['WH_capacity_size'])

# %%
df['WH_capacity_size'].value_counts()
# Out:
# WH_capacity_size
# 0    8968
# 1    8902
# 2    4280
# Name: count, dtype: int64

# %%
df['zone'] = le.fit_transform(df['zone'])

# %%
df['zone'].value_counts()
# Out:
# zone
# 1    9069
# 3    7055
# 2    5644
# 0     382
# Name: count, dtype: int64

# %%
df['WH_regional_zone'] = le.fit_transform(df['WH_regional_zone'])

# %%
df['WH_regional_zone'].value_counts()
# Out:
# WH_regional_zone
# 5    7376
# 4    4045
# 3    3708
# 1    2642
# 2    2552
# 0    1827
# Name: count, dtype: int64

# %%
df['wh_owner_type'] = le.fit_transform(df['wh_owner_type'])

# %%
df['wh_owner_type'] .value_counts()
# Out:
# wh_owner_type
# 0    12035
# 1    10115
# Name: count, dtype: int64

# %%
df['approved_wh_govt_certificate'] = le.fit_transform(df['approved_wh_govt_certificate'])

# %%
df['approved_wh_govt_certificate'].value_counts()
# Out:
# approved_wh_govt_certificate
# 4    4859
# 3    4321
# 2    4269
# 0    4158
# 1    3738
# 5     805
# Name: count, dtype: int64

# %%
# Robuus scaler is not sesitive with the outlier 
#trained data is also called as seen data , test data is also called as unseen data

# %%
# Step1 :
# Independent Column
X = df.drop(columns = 'product_wg_ton' , axis = 1)
# Dependent Column / Target column 
Y = df['product_wg_ton']

# %%
# Step2 : Split the data into train and test 
# Train data : Seen Data and Test Data : Unseen Data 
from slearn.preprocessing import train_test_split

X_train, X_test ,Y_train, Y_test = train_test_split(X,y, test_size-0.30, random_state=42

# %%
# Out:
#        Location_type  WH_capacity_size  zone  WH_regional_zone  \
# 0                  1                 2     3                 5
# 1                  0                 0     1                 4
# 2                  0                 1     2                 1
# 3                  0                 1     1                 2
# 4                  0                 0     1                 4
# ...              ...               ...   ...               ...
# 22145              0                 0     1                 5
# 22146              0                 2     2                 5
# 22147              0                 0     1                 5
# 22148              0                 0     1                 5
# 22149              0                 1     0                 3
#
#        num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                       3                    1                  2
# 1                       0                    0                  4
# ...
